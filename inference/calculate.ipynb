# %%
import torch
import numpy as np
import torch
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, matthews_corrcoef, roc_curve
from datasets import load_metric
metric_accuracy = load_metric("accuracy")
metric_f1 = load_metric("f1")
import warnings; warnings.simplefilter('ignore')
import os
# Out:
# /local/slurmtmp.1043088/ipykernel_2187326/2731833383.py:6: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric_accuracy = load_metric("accuracy")
# /home/syafiq/.local/lib/python3.11/site-packages/datasets/load.py:756: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.18.0/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/syafiq/.local/lib/python3.11/site-packages/datasets/load.py:756: FutureWarning: The repository for f1 contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.18.0/metrics/f1/f1.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(

# %%
def calculate_vul_det_score(predictions, ground_truth, target_fpr=0.005):
    """
    Calculate the vulnerability detection score (VD-S) given a tolerable FPR.
    
    Args:
    - predictions: List of model prediction probabilities for the positive class.
    - ground_truth: List of ground truth labels, where 1 means vulnerable class, and 0 means benign class.
    - target_fpr: The tolerable false positive rate.
    
    Returns:
    - vds: Calculated vulnerability detection score given the acceptable .
    - threshold: The classification threshold for vulnerable prediction.
    """
    predictions = predictions.tolist()
    ground_truth = ground_truth.tolist()

    # Calculate FPR, TPR, and thresholds using ROC curve
    fpr, tpr, thresholds = roc_curve(ground_truth, predictions)
    
    # Filter thresholds where FPR is less than or equal to the target FPR
    valid_indices = np.where(fpr <= target_fpr)[0]
    
    # Choose the threshold with the largest FPR that is still below the target FPR, if possible
    if len(valid_indices) > 0:
        idx = valid_indices[-1]  # Last index where FPR is below or equal to target FPR
    else:
        # If no such threshold exists (unlikely), default to the closest to the target FPR
        idx = np.abs(fpr - target_fpr).argmin()
        
    chosen_threshold = thresholds[idx]
    
    # Classify predictions based on the chosen threshold
    classified_preds = [1 if pred >= chosen_threshold else 0 for pred in predictions]
    
    # Calculate VD-S
    fn = sum([1 for i in range(len(ground_truth)) if ground_truth[i] == 1 and classified_preds[i] == 0])
    tp = sum([1 for i in range(len(ground_truth)) if ground_truth[i] == 1 and classified_preds[i] == 1])
    vds = fn / (fn + tp) if (fn + tp) > 0 else 0
    
    return vds, chosen_threshold

def calmetrics(prediction_file, label_file):
    all_predictions = torch.load(prediction_file, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
    all_labels = torch.load(label_file, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
    accuracy = metric_accuracy.compute(predictions=all_predictions, references=all_labels)["accuracy"]
    f1 = metric_f1.compute(predictions=all_predictions, references=all_labels)["f1"]
    precision = precision_score(all_labels.cpu(), all_predictions.cpu())
    recall = recall_score(all_labels.cpu(), all_predictions.cpu())
    tn, fp, fn, tp = confusion_matrix(all_labels.cpu(), all_predictions.cpu()).ravel()
    fpr = fp / (fp + tn)
    vds, threshold = calculate_vul_det_score(all_predictions, all_labels, target_fpr=0.005)
    #print(f"{vds:.2f} & {accuracy*100:.2f} & {f1:.4f} & {precision:.4f} & {recall:.4f} & {fpr:.4f} & {tp} & {tn} & {fp} & {fn} \\\\")
    print(f"{accuracy*100:.2f} & {f1*100:.2f} & {precision*100:.2f} & {recall*100:.2f} & {fpr*100:.2f} & {tp} & {tn} & {fp} & {fn} \\\\")
    return accuracy, f1, precision, recall, fpr, vds

# %%
directory = "pred_label"  # Replace with your actual path

cwes = ["119", "125", "787", "20", "476", "200", "416", "703", "190", "399"]
models = {"unixcoder": "unixcoder-base", "codebert": "codebert-base"}
# Dictionary to store best F1 score and identifier for each model-CWE pair
best_results = {}

# Loop through each model and CWE
for model_name in models.values():
    for cwe in cwes:
        best_f1 = 0  # Initialize best F1 score for this model-CWE pair
        best_identifier = None  # Store the identifier with the best F1 score
        
        for identifier in range(10):  # Assuming identifiers are in the range 0-9
            # Construct file paths
            prediction_file = f"{model_name}_{cwe}_{identifier}_predictions.pt"
            label_file = f"{model_name}_{cwe}_{identifier}_labels.pt"
            pred_path = os.path.join(directory, prediction_file)
            label_path = os.path.join(directory, label_file)
            
            # Check if both files exist
            if os.path.isfile(pred_path) and os.path.isfile(label_path):
                print(f"Processing {model_name} for CWE {cwe}, identifier {identifier}")
                
                # Calculate metrics
                accuracy, f1, precision, recall, fpr, vds = calmetrics(pred_path, label_path)
                
                # Track the best F1 score and identifier
                if f1 > best_f1:
                    best_f1 = f1
                    best_identifier = identifier
        
        # Store the best identifier and F1 score for this model and CWE
        best_results[(model_name, cwe)] = {"best_identifier": best_identifier, "best_f1": best_f1}

# Print the best identifier based on the highest F1 score for each model and CWE
for (model_name, cwe), result in best_results.items():
    print(f"Best identifier for {model_name} with CWE {cwe} is {result['best_identifier']} with F1 score {result['best_f1']:.4f}")
    prediction_file = f"{model_name}_{cwe}_{result['best_identifier']}_predictions.pt"
    label_file = f"{model_name}_{cwe}_{result['best_identifier']}_labels.pt"
    pred_path = os.path.join(directory, prediction_file)
    label_path = os.path.join(directory, label_file)
    calmetrics(pred_path, label_path)
# Out:
# Processing unixcoder-base for CWE 119, identifier 0
# 97.41 & 10.39 & 80.00 & 5.56 & 0.04 & 4 & 2588 & 1 & 68 \\
# Processing unixcoder-base for CWE 119, identifier 1
# 97.86 & 51.28 & 66.67 & 41.67 & 0.58 & 30 & 2574 & 15 & 42 \\
# Processing unixcoder-base for CWE 119, identifier 2
# 97.75 & 58.90 & 58.11 & 59.72 & 1.20 & 43 & 2558 & 31 & 29 \\
# Processing unixcoder-base for CWE 119, identifier 3
# 97.75 & 58.33 & 58.33 & 58.33 & 1.16 & 42 & 2559 & 30 & 30 \\
# Processing unixcoder-base for CWE 119, identifier 4
# 97.78 & 52.80 & 62.26 & 45.83 & 0.77 & 33 & 2569 & 20 & 39 \\
# Processing unixcoder-base for CWE 119, identifier 5
# 97.56 & 53.24 & 55.22 & 51.39 & 1.16 & 37 & 2559 & 30 & 35 \\
# Processing unixcoder-base for CWE 119, identifier 6
# 97.63 & 55.32 & 56.52 & 54.17 & 1.16 & 39 & 2559 & 30 & 33 \\
# Processing unixcoder-base for CWE 119, identifier 7
# 97.56 & 52.55 & 55.38 & 50.00 & 1.12 & 36 & 2560 & 29 & 36 \\
# Processing unixcoder-base for CWE 119, identifier 8
# 97.78 & 54.96 & 61.02 & 50.00 & 0.89 & 36 & 2566 & 23 & 36 \\
# Processing unixcoder-base for CWE 119, identifier 9
# 97.75 & 54.55 & 60.00 & 50.00 & 0.93 & 36 & 2565 & 24 & 36 \\
# Processing unixcoder-base for CWE 125, identifier 0
# 97.33 & 17.28 & 53.85 & 10.29 & 0.25 & 7 & 2432 & 6 & 61 \\
# Processing unixcoder-base for CWE 125, identifier 1
# 97.29 & 29.17 & 50.00 & 20.59 & 0.57 & 14 & 2424 & 14 & 54 \\
# Processing unixcoder-base for CWE 125, identifier 2
# 97.57 & 32.97 & 65.22 & 22.06 & 0.33 & 15 & 2430 & 8 & 53 \\
# Processing unixcoder-base for CWE 125, identifier 3
# 97.45 & 45.76 & 54.00 & 39.71 & 0.94 & 27 & 2415 & 23 & 41 \\
# Processing unixcoder-base for CWE 125, identifier 4
# 97.45 & 44.83 & 54.17 & 38.24 & 0.90 & 26 & 2416 & 22 & 42 \\
# Processing unixcoder-base for CWE 125, identifier 5
# 97.73 & 55.12 & 59.32 & 51.47 & 0.98 & 35 & 2414 & 24 & 33 \\
# Processing unixcoder-base for CWE 125, identifier 6
# 97.77 & 48.15 & 65.00 & 38.24 & 0.57 & 26 & 2424 & 14 & 42 \\
# Processing unixcoder-base for CWE 125, identifier 7
# 97.85 & 52.63 & 65.22 & 44.12 & 0.66 & 30 & 2422 & 16 & 38 \\
# Processing unixcoder-base for CWE 125, identifier 8
# 97.77 & 51.72 & 62.50 & 44.12 & 0.74 & 30 & 2420 & 18 & 38 \\
# Processing unixcoder-base for CWE 125, identifier 9
# 97.65 & 50.42 & 58.82 & 44.12 & 0.86 & 30 & 2417 & 21 & 38 \\
# Processing unixcoder-base for CWE 787, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1815 & 0 & 51 \\
# Processing unixcoder-base for CWE 787, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1815 & 0 & 51 \\
# Processing unixcoder-base for CWE 787, identifier 2
# 97.37 & 22.22 & 58.33 & 13.73 & 0.28 & 7 & 1810 & 5 & 44 \\
# Processing unixcoder-base for CWE 787, identifier 3
# 97.53 & 20.69 & 85.71 & 11.76 & 0.06 & 6 & 1814 & 1 & 45 \\
# Processing unixcoder-base for CWE 787, identifier 4
# 97.59 & 32.84 & 68.75 & 21.57 & 0.28 & 11 & 1810 & 5 & 40 \\
# Processing unixcoder-base for CWE 787, identifier 5
# 97.48 & 29.85 & 62.50 & 19.61 & 0.33 & 10 & 1809 & 6 & 41 \\
# Processing unixcoder-base for CWE 787, identifier 6
# 97.32 & 32.43 & 52.17 & 23.53 & 0.61 & 12 & 1804 & 11 & 39 \\
# Processing unixcoder-base for CWE 787, identifier 7
# 97.27 & 37.04 & 50.00 & 29.41 & 0.83 & 15 & 1800 & 15 & 36 \\
# Processing unixcoder-base for CWE 787, identifier 8
# 97.48 & 37.33 & 58.33 & 27.45 & 0.55 & 14 & 1805 & 10 & 37 \\
# Processing unixcoder-base for CWE 787, identifier 9
# 97.37 & 30.99 & 55.00 & 21.57 & 0.50 & 11 & 1806 & 9 & 40 \\
# Processing unixcoder-base for CWE 20, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1696 & 0 & 48 \\
# Processing unixcoder-base for CWE 20, identifier 1
# 97.48 & 48.84 & 55.26 & 43.75 & 1.00 & 21 & 1679 & 17 & 27 \\
# Processing unixcoder-base for CWE 20, identifier 2
# 97.53 & 49.41 & 56.76 & 43.75 & 0.94 & 21 & 1680 & 16 & 27 \\
# Processing unixcoder-base for CWE 20, identifier 3
# 97.76 & 45.07 & 69.57 & 33.33 & 0.41 & 16 & 1689 & 7 & 32 \\
# Processing unixcoder-base for CWE 20, identifier 4
# 97.42 & 45.78 & 54.29 & 39.58 & 0.94 & 19 & 1680 & 16 & 29 \\
# Processing unixcoder-base for CWE 20, identifier 5
# 97.71 & 51.22 & 61.76 & 43.75 & 0.77 & 21 & 1683 & 13 & 27 \\
# Processing unixcoder-base for CWE 20, identifier 6
# 97.76 & 46.58 & 68.00 & 35.42 & 0.47 & 17 & 1688 & 8 & 31 \\
# Processing unixcoder-base for CWE 20, identifier 7
# 97.65 & 53.93 & 58.54 & 50.00 & 1.00 & 24 & 1679 & 17 & 24 \\
# Processing unixcoder-base for CWE 20, identifier 8
# 97.99 & 59.77 & 66.67 & 54.17 & 0.77 & 26 & 1683 & 13 & 22 \\
# Processing unixcoder-base for CWE 20, identifier 9
# 97.99 & 55.70 & 70.97 & 45.83 & 0.53 & 22 & 1687 & 9 & 26 \\
# Processing unixcoder-base for CWE 476, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1343 & 0 & 38 \\
# Processing unixcoder-base for CWE 476, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1343 & 0 & 38 \\
# Processing unixcoder-base for CWE 476, identifier 2
# 97.68 & 42.86 & 66.67 & 31.58 & 0.45 & 12 & 1337 & 6 & 26 \\
# Processing unixcoder-base for CWE 476, identifier 3
# 98.19 & 57.63 & 80.95 & 44.74 & 0.30 & 17 & 1339 & 4 & 21 \\
# Processing unixcoder-base for CWE 476, identifier 4
# 98.12 & 55.17 & 80.00 & 42.11 & 0.30 & 16 & 1339 & 4 & 22 \\
# Processing unixcoder-base for CWE 476, identifier 5
# 97.76 & 53.73 & 62.07 & 47.37 & 0.82 & 18 & 1332 & 11 & 20 \\
# Processing unixcoder-base for CWE 476, identifier 6
# 97.61 & 52.17 & 58.06 & 47.37 & 0.97 & 18 & 1330 & 13 & 20 \\
# Processing unixcoder-base for CWE 476, identifier 7
# 97.54 & 55.26 & 55.26 & 55.26 & 1.27 & 21 & 1326 & 17 & 17 \\
# Processing unixcoder-base for CWE 476, identifier 8
# 97.76 & 55.07 & 61.29 & 50.00 & 0.89 & 19 & 1331 & 12 & 19 \\
# Processing unixcoder-base for CWE 476, identifier 9
# 97.76 & 53.73 & 62.07 & 47.37 & 0.82 & 18 & 1332 & 11 & 20 \\
# Processing unixcoder-base for CWE 200, identifier 0
# 97.22 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1156 & 0 & 33 \\
# Processing unixcoder-base for CWE 200, identifier 1
# 97.56 & 50.85 & 57.69 & 45.45 & 0.95 & 15 & 1145 & 11 & 18 \\
# Processing unixcoder-base for CWE 200, identifier 2
# 97.65 & 41.67 & 66.67 & 30.30 & 0.43 & 10 & 1151 & 5 & 23 \\
# Processing unixcoder-base for CWE 200, identifier 3
# 97.90 & 56.14 & 66.67 & 48.48 & 0.69 & 16 & 1148 & 8 & 17 \\
# Processing unixcoder-base for CWE 200, identifier 4
# 97.48 & 50.00 & 55.56 & 45.45 & 1.04 & 15 & 1144 & 12 & 18 \\
# Processing unixcoder-base for CWE 200, identifier 5
# 97.98 & 53.85 & 73.68 & 42.42 & 0.43 & 14 & 1151 & 5 & 19 \\
# Processing unixcoder-base for CWE 200, identifier 6
# 97.98 & 55.56 & 71.43 & 45.45 & 0.52 & 15 & 1150 & 6 & 18 \\
# Processing unixcoder-base for CWE 200, identifier 7
# 97.81 & 50.00 & 68.42 & 39.39 & 0.52 & 13 & 1150 & 6 & 20 \\
# Processing unixcoder-base for CWE 200, identifier 8
# 98.23 & 64.41 & 73.08 & 57.58 & 0.61 & 19 & 1149 & 7 & 14 \\
# Processing unixcoder-base for CWE 200, identifier 9
# 97.98 & 53.85 & 73.68 & 42.42 & 0.43 & 14 & 1151 & 5 & 19 \\
# Processing unixcoder-base for CWE 416, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing unixcoder-base for CWE 416, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing unixcoder-base for CWE 416, identifier 2
# 97.71 & 39.02 & 72.73 & 26.67 & 0.28 & 8 & 1059 & 3 & 22 \\
# Processing unixcoder-base for CWE 416, identifier 3
# 97.80 & 42.86 & 75.00 & 30.00 & 0.28 & 9 & 1059 & 3 & 21 \\
# Processing unixcoder-base for CWE 416, identifier 4
# 97.34 & 12.12 & 66.67 & 6.67 & 0.09 & 2 & 1061 & 1 & 28 \\
# Processing unixcoder-base for CWE 416, identifier 5
# 97.89 & 41.03 & 88.89 & 26.67 & 0.09 & 8 & 1061 & 1 & 22 \\
# Processing unixcoder-base for CWE 416, identifier 6
# 97.80 & 33.33 & 100.00 & 20.00 & 0.00 & 6 & 1062 & 0 & 24 \\
# Processing unixcoder-base for CWE 416, identifier 7
# 97.99 & 45.00 & 90.00 & 30.00 & 0.09 & 9 & 1061 & 1 & 21 \\
# Processing unixcoder-base for CWE 416, identifier 8
# 97.89 & 41.03 & 88.89 & 26.67 & 0.09 & 8 & 1061 & 1 & 22 \\
# Processing unixcoder-base for CWE 416, identifier 9
# 97.80 & 36.84 & 87.50 & 23.33 & 0.09 & 7 & 1061 & 1 & 23 \\
# Processing unixcoder-base for CWE 703, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 926 & 0 & 26 \\
# Processing unixcoder-base for CWE 703, identifier 1
# 97.37 & 7.41 & 100.00 & 3.85 & 0.00 & 1 & 926 & 0 & 25 \\
# Processing unixcoder-base for CWE 703, identifier 2
# 97.79 & 32.26 & 100.00 & 19.23 & 0.00 & 5 & 926 & 0 & 21 \\
# Processing unixcoder-base for CWE 703, identifier 3
# 97.69 & 47.62 & 62.50 & 38.46 & 0.65 & 10 & 920 & 6 & 16 \\
# Processing unixcoder-base for CWE 703, identifier 4
# 97.90 & 37.50 & 100.00 & 23.08 & 0.00 & 6 & 926 & 0 & 20 \\
# Processing unixcoder-base for CWE 703, identifier 5
# 97.58 & 41.03 & 61.54 & 30.77 & 0.54 & 8 & 921 & 5 & 18 \\
# Processing unixcoder-base for CWE 703, identifier 6
# 97.37 & 44.44 & 52.63 & 38.46 & 0.97 & 10 & 917 & 9 & 16 \\
# Processing unixcoder-base for CWE 703, identifier 7
# 97.48 & 29.41 & 62.50 & 19.23 & 0.32 & 5 & 923 & 3 & 21 \\
# Processing unixcoder-base for CWE 703, identifier 8
# 97.37 & 44.44 & 52.63 & 38.46 & 0.97 & 10 & 917 & 9 & 16 \\
# Processing unixcoder-base for CWE 703, identifier 9
# 97.69 & 35.29 & 75.00 & 23.08 & 0.22 & 6 & 924 & 2 & 20 \\
# Processing unixcoder-base for CWE 190, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 821 & 0 & 23 \\
# Processing unixcoder-base for CWE 190, identifier 1
# 97.16 & 0.00 & 0.00 & 0.00 & 0.12 & 0 & 820 & 1 & 23 \\
# Processing unixcoder-base for CWE 190, identifier 2
# 97.16 & 7.69 & 33.33 & 4.35 & 0.24 & 1 & 819 & 2 & 22 \\
# Processing unixcoder-base for CWE 190, identifier 3
# 96.45 & 25.00 & 29.41 & 21.74 & 1.46 & 5 & 809 & 12 & 18 \\
# Processing unixcoder-base for CWE 190, identifier 4
# 96.92 & 18.75 & 33.33 & 13.04 & 0.73 & 3 & 815 & 6 & 20 \\
# Processing unixcoder-base for CWE 190, identifier 5
# 96.21 & 11.11 & 15.38 & 8.70 & 1.34 & 2 & 810 & 11 & 21 \\
# Processing unixcoder-base for CWE 190, identifier 6
# 96.56 & 25.64 & 31.25 & 21.74 & 1.34 & 5 & 810 & 11 & 18 \\
# Processing unixcoder-base for CWE 190, identifier 7
# 97.27 & 34.29 & 50.00 & 26.09 & 0.73 & 6 & 815 & 6 & 17 \\
# Processing unixcoder-base for CWE 190, identifier 8
# 97.04 & 28.57 & 41.67 & 21.74 & 0.85 & 5 & 814 & 7 & 18 \\
# Processing unixcoder-base for CWE 190, identifier 9
# 96.80 & 34.15 & 38.89 & 30.43 & 1.34 & 7 & 810 & 11 & 16 \\
# Processing unixcoder-base for CWE 399, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing unixcoder-base for CWE 399, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing unixcoder-base for CWE 399, identifier 2
# 97.66 & 45.16 & 63.64 & 35.00 & 0.57 & 7 & 702 & 4 & 13 \\
# Processing unixcoder-base for CWE 399, identifier 3
# 97.52 & 25.00 & 75.00 & 15.00 & 0.14 & 3 & 705 & 1 & 17 \\
# Processing unixcoder-base for CWE 399, identifier 4
# 97.25 & 37.50 & 50.00 & 30.00 & 0.85 & 6 & 700 & 6 & 14 \\
# Processing unixcoder-base for CWE 399, identifier 5
# 97.25 & 33.33 & 50.00 & 25.00 & 0.71 & 5 & 701 & 5 & 15 \\
# Processing unixcoder-base for CWE 399, identifier 6
# 97.11 & 36.36 & 46.15 & 30.00 & 0.99 & 6 & 699 & 7 & 14 \\
# Processing unixcoder-base for CWE 399, identifier 7
# 97.11 & 27.59 & 44.44 & 20.00 & 0.71 & 4 & 701 & 5 & 16 \\
# Processing unixcoder-base for CWE 399, identifier 8
# 96.97 & 35.29 & 42.86 & 30.00 & 1.13 & 6 & 698 & 8 & 14 \\
# Processing unixcoder-base for CWE 399, identifier 9
# 97.11 & 36.36 & 46.15 & 30.00 & 0.99 & 6 & 699 & 7 & 14 \\
# Processing codebert-base for CWE 119, identifier 0
# 97.29 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 2589 & 0 & 72 \\
# Processing codebert-base for CWE 119, identifier 1
# 97.82 & 50.00 & 65.91 & 40.28 & 0.58 & 29 & 2574 & 15 & 43 \\
# Processing codebert-base for CWE 119, identifier 2
# 97.56 & 54.55 & 54.93 & 54.17 & 1.24 & 39 & 2557 & 32 & 33 \\
# Processing codebert-base for CWE 119, identifier 3
# 97.56 & 53.90 & 55.07 & 52.78 & 1.20 & 38 & 2558 & 31 & 34 \\
# Processing codebert-base for CWE 119, identifier 4
# 97.56 & 53.24 & 55.22 & 51.39 & 1.16 & 37 & 2559 & 30 & 35 \\
# Processing codebert-base for CWE 119, identifier 5
# 97.56 & 50.38 & 55.93 & 45.83 & 1.00 & 33 & 2563 & 26 & 39 \\
# Processing codebert-base for CWE 119, identifier 6
# 97.07 & 45.07 & 45.71 & 44.44 & 1.47 & 32 & 2551 & 38 & 40 \\
# Processing codebert-base for CWE 119, identifier 7
# 97.52 & 48.44 & 55.36 & 43.06 & 0.97 & 31 & 2564 & 25 & 41 \\
# Processing codebert-base for CWE 119, identifier 8
# 97.37 & 48.53 & 51.56 & 45.83 & 1.20 & 33 & 2558 & 31 & 39 \\
# Processing codebert-base for CWE 119, identifier 9
# 97.41 & 46.51 & 52.63 & 41.67 & 1.04 & 30 & 2562 & 27 & 42 \\
# Processing codebert-base for CWE 125, identifier 0
# 97.29 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 2438 & 0 & 68 \\
# Processing codebert-base for CWE 125, identifier 1
# 97.37 & 5.71 & 100.00 & 2.94 & 0.00 & 2 & 2438 & 0 & 66 \\
# Processing codebert-base for CWE 125, identifier 2
# 97.61 & 40.00 & 62.50 & 29.41 & 0.49 & 20 & 2426 & 12 & 48 \\
# Processing codebert-base for CWE 125, identifier 3
# 97.41 & 48.00 & 52.63 & 44.12 & 1.11 & 30 & 2411 & 27 & 38 \\
# Processing codebert-base for CWE 125, identifier 4
# 97.57 & 47.86 & 57.14 & 41.18 & 0.86 & 28 & 2417 & 21 & 40 \\
# Processing codebert-base for CWE 125, identifier 5
# 97.65 & 53.54 & 57.63 & 50.00 & 1.03 & 34 & 2413 & 25 & 34 \\
# Processing codebert-base for CWE 125, identifier 6
# 97.73 & 47.71 & 63.41 & 38.24 & 0.62 & 26 & 2423 & 15 & 42 \\
# Processing codebert-base for CWE 125, identifier 7
# 97.57 & 42.99 & 58.97 & 33.82 & 0.66 & 23 & 2422 & 16 & 45 \\
# Processing codebert-base for CWE 125, identifier 8
# 97.53 & 48.33 & 55.77 & 42.65 & 0.94 & 29 & 2415 & 23 & 39 \\
# Processing codebert-base for CWE 125, identifier 9
# 97.53 & 48.33 & 55.77 & 42.65 & 0.94 & 29 & 2415 & 23 & 39 \\
# Processing codebert-base for CWE 787, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1815 & 0 & 51 \\
# Processing codebert-base for CWE 787, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1815 & 0 & 51 \\
# Processing codebert-base for CWE 787, identifier 2
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1815 & 0 & 51 \\
# Processing codebert-base for CWE 787, identifier 3
# 97.48 & 17.54 & 83.33 & 9.80 & 0.06 & 5 & 1814 & 1 & 46 \\
# Processing codebert-base for CWE 787, identifier 4
# 97.59 & 23.73 & 87.50 & 13.73 & 0.06 & 7 & 1814 & 1 & 44 \\
# Processing codebert-base for CWE 787, identifier 5
# 97.43 & 35.14 & 56.52 & 25.49 & 0.55 & 13 & 1805 & 10 & 38 \\
# Processing codebert-base for CWE 787, identifier 6
# 97.43 & 33.33 & 57.14 & 23.53 & 0.50 & 12 & 1806 & 9 & 39 \\
# Processing codebert-base for CWE 787, identifier 7
# 97.59 & 36.62 & 65.00 & 25.49 & 0.39 & 13 & 1808 & 7 & 38 \\
# Processing codebert-base for CWE 787, identifier 8
# 97.53 & 37.84 & 60.87 & 27.45 & 0.50 & 14 & 1806 & 9 & 37 \\
# Processing codebert-base for CWE 787, identifier 9
# 97.59 & 38.36 & 63.64 & 27.45 & 0.44 & 14 & 1807 & 8 & 37 \\
# Processing codebert-base for CWE 20, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1696 & 0 & 48 \\
# Processing codebert-base for CWE 20, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1696 & 0 & 48 \\
# Processing codebert-base for CWE 20, identifier 2
# 97.42 & 32.84 & 57.89 & 22.92 & 0.47 & 11 & 1688 & 8 & 37 \\
# Processing codebert-base for CWE 20, identifier 3
# 97.31 & 31.88 & 52.38 & 22.92 & 0.59 & 11 & 1686 & 10 & 37 \\
# Processing codebert-base for CWE 20, identifier 4
# 97.65 & 51.76 & 59.46 & 45.83 & 0.88 & 22 & 1681 & 15 & 26 \\
# Processing codebert-base for CWE 20, identifier 5
# 97.94 & 55.00 & 68.75 & 45.83 & 0.59 & 22 & 1686 & 10 & 26 \\
# Processing codebert-base for CWE 20, identifier 6
# 97.76 & 50.63 & 64.52 & 41.67 & 0.65 & 20 & 1685 & 11 & 28 \\
# Processing codebert-base for CWE 20, identifier 7
# 97.36 & 46.51 & 52.63 & 41.67 & 1.06 & 20 & 1678 & 18 & 28 \\
# Processing codebert-base for CWE 20, identifier 8
# 97.53 & 48.19 & 57.14 & 41.67 & 0.88 & 20 & 1681 & 15 & 28 \\
# Processing codebert-base for CWE 20, identifier 9
# 97.65 & 45.33 & 62.96 & 35.42 & 0.59 & 17 & 1686 & 10 & 31 \\
# Processing codebert-base for CWE 476, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1343 & 0 & 38 \\
# Processing codebert-base for CWE 476, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1343 & 0 & 38 \\
# Processing codebert-base for CWE 476, identifier 2
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1343 & 0 & 38 \\
# Processing codebert-base for CWE 476, identifier 3
# 97.25 & 17.39 & 50.00 & 10.53 & 0.30 & 4 & 1339 & 4 & 34 \\
# Processing codebert-base for CWE 476, identifier 4
# 97.25 & 9.52 & 50.00 & 5.26 & 0.15 & 2 & 1341 & 2 & 36 \\
# Processing codebert-base for CWE 476, identifier 5
# 97.76 & 41.51 & 73.33 & 28.95 & 0.30 & 11 & 1339 & 4 & 27 \\
# Processing codebert-base for CWE 476, identifier 6
# 97.68 & 40.74 & 68.75 & 28.95 & 0.37 & 11 & 1338 & 5 & 27 \\
# Processing codebert-base for CWE 476, identifier 7
# 97.54 & 34.62 & 64.29 & 23.68 & 0.37 & 9 & 1338 & 5 & 29 \\
# Processing codebert-base for CWE 476, identifier 8
# 97.47 & 40.68 & 57.14 & 31.58 & 0.67 & 12 & 1334 & 9 & 26 \\
# Processing codebert-base for CWE 476, identifier 9
# 97.54 & 34.62 & 64.29 & 23.68 & 0.37 & 9 & 1338 & 5 & 29 \\
# Processing codebert-base for CWE 200, identifier 0
# 97.22 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1156 & 0 & 33 \\
# Processing codebert-base for CWE 200, identifier 1
# 96.47 & 40.00 & 37.84 & 42.42 & 1.99 & 14 & 1133 & 23 & 19 \\
# Processing codebert-base for CWE 200, identifier 2
# 97.22 & 5.71 & 50.00 & 3.03 & 0.09 & 1 & 1155 & 1 & 32 \\
# Processing codebert-base for CWE 200, identifier 3
# 97.56 & 45.28 & 60.00 & 36.36 & 0.69 & 12 & 1148 & 8 & 21 \\
# Processing codebert-base for CWE 200, identifier 4
# 97.81 & 45.83 & 73.33 & 33.33 & 0.35 & 11 & 1152 & 4 & 22 \\
# Processing codebert-base for CWE 200, identifier 5
# 97.81 & 50.00 & 68.42 & 39.39 & 0.52 & 13 & 1150 & 6 & 20 \\
# Processing codebert-base for CWE 200, identifier 6
# 97.73 & 40.00 & 75.00 & 27.27 & 0.26 & 9 & 1153 & 3 & 24 \\
# Processing codebert-base for CWE 200, identifier 7
# 97.48 & 37.50 & 60.00 & 27.27 & 0.52 & 9 & 1150 & 6 & 24 \\
# Processing codebert-base for CWE 200, identifier 8
# 97.39 & 45.61 & 54.17 & 39.39 & 0.95 & 13 & 1145 & 11 & 20 \\
# Processing codebert-base for CWE 200, identifier 9
# 97.39 & 36.73 & 56.25 & 27.27 & 0.61 & 9 & 1149 & 7 & 24 \\
# Processing codebert-base for CWE 416, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing codebert-base for CWE 416, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing codebert-base for CWE 416, identifier 2
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing codebert-base for CWE 416, identifier 3
# 97.07 & 15.79 & 37.50 & 10.00 & 0.47 & 3 & 1057 & 5 & 27 \\
# Processing codebert-base for CWE 416, identifier 4
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 1062 & 0 & 30 \\
# Processing codebert-base for CWE 416, identifier 5
# 97.53 & 22.86 & 80.00 & 13.33 & 0.09 & 4 & 1061 & 1 & 26 \\
# Processing codebert-base for CWE 416, identifier 6
# 97.07 & 27.27 & 42.86 & 20.00 & 0.75 & 6 & 1054 & 8 & 24 \\
# Processing codebert-base for CWE 416, identifier 7
# 97.62 & 27.78 & 83.33 & 16.67 & 0.09 & 5 & 1061 & 1 & 25 \\
# Processing codebert-base for CWE 416, identifier 8
# 97.34 & 29.27 & 54.55 & 20.00 & 0.47 & 6 & 1057 & 5 & 24 \\
# Processing codebert-base for CWE 416, identifier 9
# 97.44 & 30.00 & 60.00 & 20.00 & 0.38 & 6 & 1058 & 4 & 24 \\
# Processing codebert-base for CWE 703, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 926 & 0 & 26 \\
# Processing codebert-base for CWE 703, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 926 & 0 & 26 \\
# Processing codebert-base for CWE 703, identifier 2
# 97.69 & 31.25 & 83.33 & 19.23 & 0.11 & 5 & 925 & 1 & 21 \\
# Processing codebert-base for CWE 703, identifier 3
# 97.69 & 42.11 & 66.67 & 30.77 & 0.43 & 8 & 922 & 4 & 18 \\
# Processing codebert-base for CWE 703, identifier 4
# 97.90 & 37.50 & 100.00 & 23.08 & 0.00 & 6 & 926 & 0 & 20 \\
# Processing codebert-base for CWE 703, identifier 5
# 97.90 & 54.55 & 66.67 & 46.15 & 0.65 & 12 & 920 & 6 & 14 \\
# Processing codebert-base for CWE 703, identifier 6
# 97.90 & 50.00 & 71.43 & 38.46 & 0.43 & 10 & 922 & 4 & 16 \\
# Processing codebert-base for CWE 703, identifier 7
# 97.58 & 43.90 & 60.00 & 34.62 & 0.65 & 9 & 920 & 6 & 17 \\
# Processing codebert-base for CWE 703, identifier 8
# 97.90 & 52.38 & 68.75 & 42.31 & 0.54 & 11 & 921 & 5 & 15 \\
# Processing codebert-base for CWE 703, identifier 9
# 97.79 & 48.78 & 66.67 & 38.46 & 0.54 & 10 & 921 & 5 & 16 \\
# Processing codebert-base for CWE 190, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 821 & 0 & 23 \\
# Processing codebert-base for CWE 190, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 821 & 0 & 23 \\
# Processing codebert-base for CWE 190, identifier 2
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 821 & 0 & 23 \\
# Processing codebert-base for CWE 190, identifier 3
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 821 & 0 & 23 \\
# Processing codebert-base for CWE 190, identifier 4
# 95.50 & 32.14 & 27.27 & 39.13 & 2.92 & 9 & 797 & 24 & 14 \\
# Processing codebert-base for CWE 190, identifier 5
# 96.92 & 38.10 & 42.11 & 34.78 & 1.34 & 8 & 810 & 11 & 15 \\
# Processing codebert-base for CWE 190, identifier 6
# 97.51 & 43.24 & 57.14 & 34.78 & 0.73 & 8 & 815 & 6 & 15 \\
# Processing codebert-base for CWE 190, identifier 7
# 97.16 & 40.00 & 47.06 & 34.78 & 1.10 & 8 & 812 & 9 & 15 \\
# Processing codebert-base for CWE 190, identifier 8
# 97.16 & 33.33 & 46.15 & 26.09 & 0.85 & 6 & 814 & 7 & 17 \\
# Processing codebert-base for CWE 190, identifier 9
# 97.16 & 33.33 & 46.15 & 26.09 & 0.85 & 6 & 814 & 7 & 17 \\
# Processing codebert-base for CWE 399, identifier 0
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 1
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 2
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 3
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 4
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 5
# 97.25 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 706 & 0 & 20 \\
# Processing codebert-base for CWE 399, identifier 6
# 97.38 & 38.71 & 54.55 & 30.00 & 0.71 & 6 & 701 & 5 & 14 \\
# Processing codebert-base for CWE 399, identifier 7
# 97.52 & 43.75 & 58.33 & 35.00 & 0.71 & 7 & 701 & 5 & 13 \\
# Processing codebert-base for CWE 399, identifier 8
# 97.38 & 29.63 & 57.14 & 20.00 & 0.42 & 4 & 703 & 3 & 16 \\
# Processing codebert-base for CWE 399, identifier 9
# 97.25 & 23.08 & 50.00 & 15.00 & 0.42 & 3 & 703 & 3 & 17 \\
# Best identifier for unixcoder-base with CWE 119 is 2 with F1 score 0.5890
# 97.75 & 58.90 & 58.11 & 59.72 & 1.20 & 43 & 2558 & 31 & 29 \\
# Best identifier for unixcoder-base with CWE 125 is 5 with F1 score 0.5512
# 97.73 & 55.12 & 59.32 & 51.47 & 0.98 & 35 & 2414 & 24 & 33 \\
# Best identifier for unixcoder-base with CWE 787 is 8 with F1 score 0.3733
# 97.48 & 37.33 & 58.33 & 27.45 & 0.55 & 14 & 1805 & 10 & 37 \\
# Best identifier for unixcoder-base with CWE 20 is 8 with F1 score 0.5977
# 97.99 & 59.77 & 66.67 & 54.17 & 0.77 & 26 & 1683 & 13 & 22 \\
# Best identifier for unixcoder-base with CWE 476 is 3 with F1 score 0.5763
# 98.19 & 57.63 & 80.95 & 44.74 & 0.30 & 17 & 1339 & 4 & 21 \\
# Best identifier for unixcoder-base with CWE 200 is 8 with F1 score 0.6441
# 98.23 & 64.41 & 73.08 & 57.58 & 0.61 & 19 & 1149 & 7 & 14 \\
# Best identifier for unixcoder-base with CWE 416 is 7 with F1 score 0.4500
# 97.99 & 45.00 & 90.00 & 30.00 & 0.09 & 9 & 1061 & 1 & 21 \\
# Best identifier for unixcoder-base with CWE 703 is 3 with F1 score 0.4762
# 97.69 & 47.62 & 62.50 & 38.46 & 0.65 & 10 & 920 & 6 & 16 \\
# Best identifier for unixcoder-base with CWE 190 is 7 with F1 score 0.3429
# 97.27 & 34.29 & 50.00 & 26.09 & 0.73 & 6 & 815 & 6 & 17 \\
# Best identifier for unixcoder-base with CWE 399 is 2 with F1 score 0.4516
# 97.66 & 45.16 & 63.64 & 35.00 & 0.57 & 7 & 702 & 4 & 13 \\
# Best identifier for codebert-base with CWE 119 is 2 with F1 score 0.5455
# 97.56 & 54.55 & 54.93 & 54.17 & 1.24 & 39 & 2557 & 32 & 33 \\
# Best identifier for codebert-base with CWE 125 is 5 with F1 score 0.5354
# 97.65 & 53.54 & 57.63 & 50.00 & 1.03 & 34 & 2413 & 25 & 34 \\
# Best identifier for codebert-base with CWE 787 is 9 with F1 score 0.3836
# 97.59 & 38.36 & 63.64 & 27.45 & 0.44 & 14 & 1807 & 8 & 37 \\
# Best identifier for codebert-base with CWE 20 is 5 with F1 score 0.5500
# 97.94 & 55.00 & 68.75 & 45.83 & 0.59 & 22 & 1686 & 10 & 26 \\
# Best identifier for codebert-base with CWE 476 is 5 with F1 score 0.4151
# 97.76 & 41.51 & 73.33 & 28.95 & 0.30 & 11 & 1339 & 4 & 27 \\
# Best identifier for codebert-base with CWE 200 is 5 with F1 score 0.5000
# 97.81 & 50.00 & 68.42 & 39.39 & 0.52 & 13 & 1150 & 6 & 20 \\
# Best identifier for codebert-base with CWE 416 is 9 with F1 score 0.3000
# 97.44 & 30.00 & 60.00 & 20.00 & 0.38 & 6 & 1058 & 4 & 24 \\
# Best identifier for codebert-base with CWE 703 is 5 with F1 score 0.5455
# 97.90 & 54.55 & 66.67 & 46.15 & 0.65 & 12 & 920 & 6 & 14 \\
# Best identifier for codebert-base with CWE 190 is 6 with F1 score 0.4324
# 97.51 & 43.24 & 57.14 & 34.78 & 0.73 & 8 & 815 & 6 & 15 \\
# Best identifier for codebert-base with CWE 399 is 7 with F1 score 0.4375
# 97.52 & 43.75 & 58.33 & 35.00 & 0.71 & 7 & 701 & 5 & 13 \\

# %%
directory = "pred_label"  # Replace with your actual path

cwes = ["119", "125", "787", "20", "476", "200", "416", "703", "190", "399"]
models = {"starcoder": "starcoder2-7b"}
# Dictionary to store best F1 score and identifier for each model-CWE pair
best_results = {}

# Loop through each model and CWE
for model_name in models.values():
    for cwe in cwes:        
        # Construct file paths
        prediction_file = f"all_{model_name}_{cwe}_predictions.pt"
        label_file = f"all_{model_name}_{cwe}_labels.pt"
        pred_path = os.path.join(directory, prediction_file)
        label_path = os.path.join(directory, label_file)
        # Check if both files exist
        if os.path.isfile(pred_path) and os.path.isfile(label_path):
            print(f"Processing {model_name} for CWE {cwe}")
                
            # Calculate metrics
            accuracy, f1, precision, recall, fpr, vds = calmetrics(pred_path, label_path)
# Out:
# Processing starcoder2-7b for CWE 125
# 96.33 & 15.19 & 8.59 & 65.81 & 3.52 & 102 & 29754 & 1086 & 53 \\
# Processing starcoder2-7b for CWE 787
# 94.75 & 9.67 & 5.22 & 65.41 & 5.12 & 87 & 29282 & 1580 & 46 \\
# Processing starcoder2-7b for CWE 119
# 99.60 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 30870 & 0 & 125 \\
# Processing starcoder2-7b for CWE 20
# 98.99 & 8.21 & 6.70 & 10.61 & 0.63 & 14 & 30668 & 195 & 118 \\
# Processing starcoder2-7b for CWE 416
# 97.87 & 8.08 & 4.65 & 30.85 & 1.93 & 29 & 30306 & 595 & 65 \\
# Processing starcoder2-7b for CWE 190
# 98.53 & 16.79 & 9.91 & 54.76 & 1.35 & 46 & 30493 & 418 & 38 \\
# Processing starcoder2-7b for CWE 476
# 99.75 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 30916 & 0 & 79 \\
# Processing starcoder2-7b for CWE 200
# 97.36 & 6.63 & 3.62 & 39.19 & 2.50 & 29 & 30149 & 772 & 45 \\
# Processing starcoder2-7b for CWE 79
# 98.37 & 17.65 & 9.76 & 91.53 & 1.61 & 54 & 30437 & 499 & 5 \\
# Processing starcoder2-7b for CWE 703
# 99.82 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 30938 & 0 & 57 \\

# %%
directory = "pred_label"  # Replace with your actual path

cwes = ["2", "3", "4", "5", "6", "7", "8", "9", "10"]
models = {"starcoder": "starcoder2-7b"}
# Dictionary to store best F1 score and identifier for each model-CWE pair
best_results = {}

# Loop through each model and CWE
for model_name in models.values():
    for cwe in cwes:        
        # Construct file paths
        prediction_file = f"TOP_{model_name}_{cwe}_best_predictions.pt"
        label_file = f"TOP_{model_name}_{cwe}_best_labels.pt"
        pred_path = os.path.join(directory, prediction_file)
        label_path = os.path.join(directory, label_file)
        # Check if both files exist
        if os.path.isfile(pred_path) and os.path.isfile(label_path):
            print(f"Processing {model_name} for TOP {cwe}")
                
            # Calculate metrics
            accuracy, f1, precision, recall, fpr, vds = calmetrics(pred_path, label_path)
# Out:
# Processing starcoder2-7b for TOP 2
# 94.57 & 13.54 & 59.46 & 7.64 & 0.31 & 22 & 4868 & 15 & 266 \\
# Processing starcoder2-7b for TOP 3
# 94.44 & 5.42 & 52.17 & 2.86 & 0.15 & 12 & 7106 & 11 & 408 \\
# Processing starcoder2-7b for TOP 4
# 94.40 & 0.36 & 20.00 & 0.18 & 0.04 & 1 & 9228 & 4 & 544 \\
# Processing starcoder2-7b for TOP 5
# 94.28 & 3.81 & 30.23 & 2.03 & 0.28 & 13 & 10792 & 30 & 626 \\
# Processing starcoder2-7b for TOP 6
# 94.35 & 2.40 & 32.14 & 1.24 & 0.16 & 9 & 12225 & 19 & 714 \\
# Processing starcoder2-7b for TOP 7
# 94.44 & 0.50 & 100.00 & 0.25 & 0.00 & 2 & 13587 & 0 & 800 \\
# Processing starcoder2-7b for TOP 8
# 94.43 & 0.68 & 60.00 & 0.34 & 0.01 & 3 & 14837 & 2 & 873 \\
# Processing starcoder2-7b for TOP 9
# 94.32 & 4.99 & 37.31 & 2.67 & 0.27 & 25 & 15797 & 42 & 910 \\
# Processing starcoder2-7b for TOP 10
# 94.43 & 0.60 & 75.00 & 0.30 & 0.01 & 3 & 16792 & 1 & 989 \\

# %%
directory = "pred_label"  # Replace with your actual path

tops = ["2", "3", "4", "5", "6", "7", "8", "9", "10"]
#models = {"unixcoder": "unixcoder-base", "codebert": "codebert-base"}
models = {"unixcoder": "unixcoder-base"}
#models = {"codebert": "codebert-base"}
# Dictionary to store best F1 score and identifier for each model-TOP pair
best_results = {}

# Loop through each model and TOP
for model_name in models.values():
    for top in tops:
        best_f1 = 0  # Initialize best F1 score for this model-TOP pair
        best_identifier = None  # Store the identifier with the best F1 score
        
        for identifier in range(10):  # Assuming identifiers are in the range 0-9
            # Construct file paths
            print(model_name)
            prediction_file = f"top_{model_name}_{top}_{identifier}_predictions.pt"
            label_file = f"top_{model_name}_{top}_{identifier}_labels.pt"
            pred_path = os.path.join(directory, prediction_file)
            label_path = os.path.join(directory, label_file)
            
            # Check if both files exist
            if os.path.isfile(pred_path) and os.path.isfile(label_path):
                print(f"Processing {model_name} for TOP {top}, identifier {identifier}")
                
                # Calculate metrics
                accuracy, f1, precision, recall, fpr, vds = calmetrics(pred_path, label_path)
                
                # Track the best F1 score and identifier
                if f1 > best_f1:
                    best_f1 = f1
                    best_identifier = identifier
        
        # Store the best identifier and F1 score for this model and TOP
        best_results[(model_name, top)] = {"best_identifier": best_identifier, "best_f1": best_f1}

# Print the best identifier based on the highest F1 score for each model and TOP
for (model_name, top), result in best_results.items():
    print(f"Best identifier for {model_name} with TOP {top} is {result['best_identifier']} with F1 score {result['best_f1']:.4f}")
    prediction_file = f"top_{model_name}_{top}_{result['best_identifier']}_predictions.pt"
    label_file = f"top_{model_name}_{top}_{result['best_identifier']}_labels.pt"
    pred_path = os.path.join(directory, prediction_file)
    label_path = os.path.join(directory, label_file)
    calmetrics(pred_path, label_path)
# Out:
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 0
# 97.16 & 48.06 & 47.55 & 48.57 & 1.49 & 68 & 4952 & 75 & 72 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 1
# 97.54 & 33.51 & 62.75 & 22.86 & 0.38 & 32 & 5008 & 19 & 108 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 2
# 97.35 & 51.25 & 51.06 & 51.43 & 1.37 & 72 & 4958 & 69 & 68 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 3
# 97.39 & 44.90 & 52.38 & 39.29 & 0.99 & 55 & 4977 & 50 & 85 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 4
# 97.04 & 46.69 & 45.58 & 47.86 & 1.59 & 67 & 4947 & 80 & 73 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 5
# 97.04 & 47.06 & 45.64 & 48.57 & 1.61 & 68 & 4946 & 81 & 72 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 6
# 97.10 & 48.98 & 46.75 & 51.43 & 1.63 & 72 & 4945 & 82 & 68 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 7
# 97.46 & 49.81 & 53.72 & 46.43 & 1.11 & 65 & 4971 & 56 & 75 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 8
# 97.56 & 47.50 & 57.00 & 40.71 & 0.86 & 57 & 4984 & 43 & 83 \\
# unixcoder-base
# Processing unixcoder-base for TOP 2, identifier 9
# 97.56 & 49.19 & 56.48 & 43.57 & 0.93 & 61 & 4980 & 47 & 79 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 0
# 97.51 & 23.58 & 71.05 & 14.14 & 0.16 & 27 & 6831 & 11 & 164 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 1
# 97.34 & 6.03 & 75.00 & 3.14 & 0.03 & 6 & 6840 & 2 & 185 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 2
# 97.44 & 43.75 & 54.26 & 36.65 & 0.86 & 70 & 6783 & 59 & 121 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 3
# 97.36 & 38.00 & 52.29 & 29.84 & 0.76 & 57 & 6790 & 52 & 134 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 4
# 96.97 & 40.00 & 43.29 & 37.17 & 1.36 & 71 & 6749 & 93 & 120 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 5
# 97.10 & 42.70 & 46.06 & 39.79 & 1.30 & 76 & 6753 & 89 & 115 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 6
# 97.04 & 40.91 & 44.72 & 37.70 & 1.30 & 72 & 6753 & 89 & 119 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 7
# 97.23 & 41.44 & 48.59 & 36.13 & 1.07 & 69 & 6769 & 73 & 122 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 8
# 96.96 & 42.47 & 43.65 & 41.36 & 1.49 & 79 & 6740 & 102 & 112 \\
# unixcoder-base
# Processing unixcoder-base for TOP 3, identifier 9
# 97.16 & 42.86 & 47.17 & 39.27 & 1.23 & 75 & 6758 & 84 & 116 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 0
# 97.38 & 17.86 & 60.98 & 10.46 & 0.19 & 25 & 8522 & 16 & 214 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 1
# 97.47 & 33.93 & 58.76 & 23.85 & 0.47 & 57 & 8498 & 40 & 182 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 2
# 97.30 & 41.77 & 50.60 & 35.56 & 0.97 & 85 & 8455 & 83 & 154 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 3
# 97.16 & 33.95 & 46.38 & 26.78 & 0.87 & 64 & 8464 & 74 & 175 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 4
# 96.88 & 37.44 & 41.21 & 34.31 & 1.37 & 82 & 8421 & 117 & 157 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 5
# 96.72 & 42.40 & 40.61 & 44.35 & 1.82 & 106 & 8383 & 155 & 133 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 6
# 96.97 & 40.09 & 43.41 & 37.24 & 1.36 & 89 & 8422 & 116 & 150 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 7
# 96.83 & 38.22 & 40.76 & 35.98 & 1.46 & 86 & 8413 & 125 & 153 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 8
# 97.16 & 41.13 & 47.28 & 36.40 & 1.14 & 87 & 8441 & 97 & 152 \\
# unixcoder-base
# Processing unixcoder-base for TOP 4, identifier 9
# 97.12 & 41.30 & 46.35 & 37.24 & 1.21 & 89 & 8435 & 103 & 150 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 9881 & 0 & 277 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 1
# 97.40 & 35.92 & 54.81 & 26.71 & 0.62 & 74 & 9820 & 61 & 203 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 2
# 97.41 & 37.83 & 54.79 & 28.88 & 0.67 & 80 & 9815 & 66 & 197 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 3
# 96.80 & 45.74 & 42.55 & 49.46 & 1.87 & 137 & 9696 & 185 & 140 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 4
# 96.70 & 41.33 & 40.14 & 42.60 & 1.78 & 118 & 9705 & 176 & 159 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 5
# 96.92 & 42.14 & 43.18 & 41.16 & 1.52 & 114 & 9731 & 150 & 163 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 6
# 96.72 & 41.68 & 40.48 & 42.96 & 1.77 & 119 & 9706 & 175 & 158 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 7
# 97.09 & 38.59 & 45.37 & 33.57 & 1.13 & 93 & 9769 & 112 & 184 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 8
# 97.04 & 38.95 & 44.44 & 34.66 & 1.21 & 96 & 9761 & 120 & 181 \\
# unixcoder-base
# Processing unixcoder-base for TOP 5, identifier 9
# 97.06 & 38.60 & 44.76 & 33.94 & 1.17 & 94 & 9765 & 116 & 183 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 11037 & 0 & 310 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 1
# 97.44 & 43.71 & 54.59 & 36.45 & 0.85 & 113 & 10943 & 94 & 197 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 2
# 97.39 & 44.36 & 53.15 & 38.06 & 0.94 & 118 & 10933 & 104 & 192 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 3
# 97.31 & 36.06 & 51.50 & 27.74 & 0.73 & 86 & 10956 & 81 & 224 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 4
# 96.96 & 37.61 & 42.80 & 33.55 & 1.26 & 104 & 10898 & 139 & 206 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 5
# 96.59 & 43.00 & 39.57 & 47.10 & 2.02 & 146 & 10814 & 223 & 164 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 6
# 96.71 & 40.32 & 40.00 & 40.65 & 1.71 & 126 & 10848 & 189 & 184 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 7
# 97.02 & 38.55 & 44.17 & 34.19 & 1.21 & 106 & 10903 & 134 & 204 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 8
# 96.82 & 39.53 & 41.11 & 38.06 & 1.53 & 118 & 10868 & 169 & 192 \\
# unixcoder-base
# Processing unixcoder-base for TOP 6, identifier 9
# 96.93 & 38.52 & 42.58 & 35.16 & 1.33 & 109 & 10890 & 147 & 201 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 12099 & 0 & 340 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 1
# 97.22 & 2.81 & 31.25 & 1.47 & 0.09 & 5 & 12088 & 11 & 335 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 2
# 97.37 & 39.56 & 53.23 & 31.47 & 0.78 & 107 & 12005 & 94 & 233 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 3
# 97.41 & 34.55 & 55.92 & 25.00 & 0.55 & 85 & 12032 & 67 & 255 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 4
# 97.23 & 36.06 & 48.99 & 28.53 & 0.83 & 97 & 11998 & 101 & 243 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 5
# 97.18 & 34.15 & 47.15 & 26.76 & 0.84 & 91 & 11997 & 102 & 249 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 6
# 97.28 & 31.85 & 50.64 & 23.24 & 0.64 & 79 & 12022 & 77 & 261 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 7
# 97.22 & 26.38 & 47.69 & 18.24 & 0.56 & 62 & 12031 & 68 & 278 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 8
# 97.04 & 32.10 & 43.07 & 25.59 & 0.95 & 87 & 11984 & 115 & 253 \\
# unixcoder-base
# Processing unixcoder-base for TOP 7, identifier 9
# 96.94 & 31.35 & 40.47 & 25.59 & 1.06 & 87 & 11971 & 128 & 253 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 0
# 97.30 & 40.46 & 50.83 & 33.61 & 0.91 & 123 & 12906 & 119 & 243 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 1
# 97.46 & 38.18 & 57.07 & 28.69 & 0.61 & 105 & 12946 & 79 & 261 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 2
# 97.33 & 36.52 & 52.02 & 28.14 & 0.73 & 103 & 12930 & 95 & 263 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 3
# 96.59 & 40.73 & 38.77 & 42.90 & 1.90 & 157 & 12777 & 248 & 209 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 4
# 96.28 & 39.71 & 35.65 & 44.81 & 2.27 & 164 & 12729 & 296 & 202 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 5
# 96.48 & 38.59 & 36.91 & 40.44 & 1.94 & 148 & 12772 & 253 & 218 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 6
# 96.81 & 37.30 & 40.32 & 34.70 & 1.44 & 127 & 12837 & 188 & 239 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 7
# 96.79 & 31.75 & 37.88 & 27.32 & 1.26 & 100 & 12861 & 164 & 266 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 8
# 96.69 & 34.56 & 37.62 & 31.97 & 1.49 & 117 & 12831 & 194 & 249 \\
# unixcoder-base
# Processing unixcoder-base for TOP 8, identifier 9
# 96.72 & 32.77 & 37.28 & 29.23 & 1.38 & 107 & 12845 & 180 & 259 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 13846 & 0 & 389 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 1
# 97.31 & 4.49 & 75.00 & 2.31 & 0.02 & 9 & 13843 & 3 & 380 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 2
# 97.36 & 29.32 & 54.55 & 20.05 & 0.47 & 78 & 13781 & 65 & 311 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 3
# 97.03 & 38.07 & 44.22 & 33.42 & 1.18 & 130 & 13682 & 164 & 259 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 4
# 96.72 & 30.61 & 36.27 & 26.48 & 1.31 & 103 & 13665 & 181 & 286 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 5
# 96.78 & 29.10 & 36.58 & 24.16 & 1.18 & 94 & 13683 & 163 & 295 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 6
# 96.65 & 33.66 & 36.67 & 31.11 & 1.51 & 121 & 13637 & 209 & 268 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 7
# 96.52 & 32.43 & 34.49 & 30.59 & 1.63 & 119 & 13620 & 226 & 270 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 8
# 96.48 & 31.65 & 33.72 & 29.82 & 1.65 & 116 & 13618 & 228 & 273 \\
# unixcoder-base
# Processing unixcoder-base for TOP 9, identifier 9
# 96.49 & 29.22 & 32.59 & 26.48 & 1.54 & 103 & 13633 & 213 & 286 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 14552 & 0 & 409 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 1
# 97.27 & 0.97 & 66.67 & 0.49 & 0.01 & 2 & 14551 & 1 & 407 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 2
# 97.32 & 11.87 & 58.70 & 6.60 & 0.13 & 27 & 14533 & 19 & 382 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 3
# 97.39 & 32.70 & 55.23 & 23.23 & 0.53 & 95 & 14475 & 77 & 314 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 4
# 96.68 & 33.47 & 36.98 & 30.56 & 1.46 & 125 & 14339 & 213 & 284 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 5
# 96.41 & 34.11 & 34.24 & 33.99 & 1.83 & 139 & 14285 & 267 & 270 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 6
# 96.38 & 28.15 & 30.81 & 25.92 & 1.64 & 106 & 14314 & 238 & 303 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 7
# 96.44 & 32.10 & 33.51 & 30.81 & 1.72 & 126 & 14302 & 250 & 283 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 8
# 96.40 & 27.88 & 30.86 & 25.43 & 1.60 & 104 & 14319 & 233 & 305 \\
# unixcoder-base
# Processing unixcoder-base for TOP 10, identifier 9
# 96.48 & 29.49 & 32.64 & 26.89 & 1.56 & 110 & 14325 & 227 & 299 \\
# Best identifier for unixcoder-base with TOP 2 is 2 with F1 score 0.5125
# 97.35 & 51.25 & 51.06 & 51.43 & 1.37 & 72 & 4958 & 69 & 68 \\
# Best identifier for unixcoder-base with TOP 3 is 2 with F1 score 0.4375
# 97.44 & 43.75 & 54.26 & 36.65 & 0.86 & 70 & 6783 & 59 & 121 \\
# Best identifier for unixcoder-base with TOP 4 is 5 with F1 score 0.4240
# 96.72 & 42.40 & 40.61 & 44.35 & 1.82 & 106 & 8383 & 155 & 133 \\
# Best identifier for unixcoder-base with TOP 5 is 3 with F1 score 0.4574
# 96.80 & 45.74 & 42.55 & 49.46 & 1.87 & 137 & 9696 & 185 & 140 \\
# Best identifier for unixcoder-base with TOP 6 is 2 with F1 score 0.4436
# 97.39 & 44.36 & 53.15 & 38.06 & 0.94 & 118 & 10933 & 104 & 192 \\
# Best identifier for unixcoder-base with TOP 7 is 2 with F1 score 0.3956
# 97.37 & 39.56 & 53.23 & 31.47 & 0.78 & 107 & 12005 & 94 & 233 \\
# Best identifier for unixcoder-base with TOP 8 is 3 with F1 score 0.4073
# 96.59 & 40.73 & 38.77 & 42.90 & 1.90 & 157 & 12777 & 248 & 209 \\
# Best identifier for unixcoder-base with TOP 9 is 3 with F1 score 0.3807
# 97.03 & 38.07 & 44.22 & 33.42 & 1.18 & 130 & 13682 & 164 & 259 \\
# Best identifier for unixcoder-base with TOP 10 is 5 with F1 score 0.3411
# 96.41 & 34.11 & 34.24 & 33.99 & 1.83 & 139 & 14285 & 267 & 270 \\

# %%
directory = "pred_label"  # Replace with your actual path

tops = ["2", "3", "4", "5", "6", "7", "8", "9", "10"]
#models = {"unixcoder": "unixcoder-base", "codebert": "codebert-base"}
#models = {"unixcoder": "unixcoder-base"}
models = {"codebert": "codebert-base"}
# Dictionary to store best F1 score and identifier for each model-TOP pair
best_results = {}

# Loop through each model and TOP
for model_name in models.values():
    for top in tops:
        best_f1 = 0  # Initialize best F1 score for this model-TOP pair
        best_identifier = None  # Store the identifier with the best F1 score
        
        for identifier in range(10):  # Assuming identifiers are in the range 0-9
            # Construct file paths
            print(model_name)
            prediction_file = f"top_{model_name}_{top}_{identifier}_predictions.pt"
            label_file = f"top_{model_name}_{top}_{identifier}_labels.pt"
            pred_path = os.path.join(directory, prediction_file)
            label_path = os.path.join(directory, label_file)
            
            # Check if both files exist
            if os.path.isfile(pred_path) and os.path.isfile(label_path):
                print(f"Processing {model_name} for TOP {top}, identifier {identifier}")
                
                # Calculate metrics
                accuracy, f1, precision, recall, fpr, vds = calmetrics(pred_path, label_path)
                
                # Track the best F1 score and identifier
                if f1 > best_f1:
                    best_f1 = f1
                    best_identifier = identifier
        
        # Store the best identifier and F1 score for this model and TOP
        best_results[(model_name, top)] = {"best_identifier": best_identifier, "best_f1": best_f1}

# Print the best identifier based on the highest F1 score for each model and TOP
for (model_name, top), result in best_results.items():
    print(f"Best identifier for {model_name} with TOP {top} is {result['best_identifier']} with F1 score {result['best_f1']:.4f}")
    prediction_file = f"top_{model_name}_{top}_{result['best_identifier']}_predictions.pt"
    label_file = f"top_{model_name}_{top}_{result['best_identifier']}_labels.pt"
    pred_path = os.path.join(directory, prediction_file)
    label_path = os.path.join(directory, label_file)
    calmetrics(pred_path, label_path)
# Out:
# codebert-base
# Processing codebert-base for TOP 2, identifier 0
# 97.58 & 41.86 & 60.00 & 32.14 & 0.60 & 45 & 4997 & 30 & 95 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 1
# 97.43 & 22.22 & 61.29 & 13.57 & 0.24 & 19 & 5015 & 12 & 121 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 2
# 97.52 & 46.22 & 56.12 & 39.29 & 0.86 & 55 & 4984 & 43 & 85 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 3
# 97.64 & 40.78 & 63.64 & 30.00 & 0.48 & 42 & 5003 & 24 & 98 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 4
# 97.06 & 46.85 & 45.89 & 47.86 & 1.57 & 67 & 4948 & 79 & 73 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 5
# 97.37 & 48.09 & 51.64 & 45.00 & 1.17 & 63 & 4968 & 59 & 77 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 6
# 97.19 & 49.12 & 48.28 & 50.00 & 1.49 & 70 & 4952 & 75 & 70 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 7
# 97.56 & 47.06 & 57.14 & 40.00 & 0.84 & 56 & 4985 & 42 & 84 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 8
# 97.50 & 47.35 & 55.24 & 41.43 & 0.93 & 58 & 4980 & 47 & 82 \\
# codebert-base
# Processing codebert-base for TOP 2, identifier 9
# 97.50 & 47.35 & 55.24 & 41.43 & 0.93 & 58 & 4980 & 47 & 82 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 0
# 97.28 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 6842 & 0 & 191 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.01 & 0 & 6841 & 1 & 191 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 2
# 97.53 & 33.08 & 62.32 & 22.51 & 0.38 & 43 & 6816 & 26 & 148 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 3
# 97.27 & 29.93 & 49.40 & 21.47 & 0.61 & 41 & 6800 & 42 & 150 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 4
# 96.96 & 38.15 & 42.58 & 34.55 & 1.30 & 66 & 6753 & 89 & 125 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 5
# 97.04 & 38.46 & 44.22 & 34.03 & 1.20 & 65 & 6760 & 82 & 126 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 6
# 97.16 & 36.71 & 46.40 & 30.37 & 0.98 & 58 & 6775 & 67 & 133 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 7
# 97.17 & 33.89 & 46.36 & 26.70 & 0.86 & 51 & 6783 & 59 & 140 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 8
# 97.21 & 39.13 & 48.09 & 32.98 & 0.99 & 63 & 6774 & 68 & 128 \\
# codebert-base
# Processing codebert-base for TOP 3, identifier 9
# 97.26 & 38.73 & 49.19 & 31.94 & 0.92 & 61 & 6779 & 63 & 130 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 0
# 97.33 & 30.77 & 52.53 & 21.76 & 0.55 & 52 & 8491 & 47 & 187 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 1
# 97.38 & 20.69 & 58.82 & 12.55 & 0.25 & 30 & 8517 & 21 & 209 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 2
# 97.24 & 37.63 & 48.99 & 30.54 & 0.89 & 73 & 8462 & 76 & 166 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 3
# 97.13 & 29.61 & 44.54 & 22.18 & 0.77 & 53 & 8472 & 66 & 186 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 4
# 97.04 & 34.34 & 43.31 & 28.45 & 1.04 & 68 & 8449 & 89 & 171 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 5
# 97.07 & 39.24 & 45.11 & 34.73 & 1.18 & 83 & 8437 & 101 & 156 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 6
# 97.08 & 37.56 & 45.03 & 32.22 & 1.10 & 77 & 8444 & 94 & 162 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 7
# 97.03 & 38.88 & 44.15 & 34.73 & 1.23 & 83 & 8433 & 105 & 156 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 8
# 97.05 & 36.36 & 44.05 & 30.96 & 1.10 & 74 & 8444 & 94 & 165 \\
# codebert-base
# Processing codebert-base for TOP 4, identifier 9
# 96.95 & 36.79 & 42.16 & 32.64 & 1.25 & 78 & 8431 & 107 & 161 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 9881 & 0 & 277 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 1
# 97.35 & 26.70 & 54.44 & 17.69 & 0.41 & 49 & 9840 & 41 & 228 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 2
# 97.29 & 30.38 & 50.85 & 21.66 & 0.59 & 60 & 9823 & 58 & 217 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 3
# 96.60 & 38.06 & 37.86 & 38.27 & 1.76 & 106 & 9707 & 174 & 171 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 4
# 96.81 & 37.93 & 40.41 & 35.74 & 1.48 & 99 & 9735 & 146 & 178 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 5
# 96.76 & 33.54 & 38.07 & 29.96 & 1.37 & 83 & 9746 & 135 & 194 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 6
# 96.25 & 35.31 & 33.33 & 37.55 & 2.11 & 104 & 9673 & 208 & 173 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 7
# 96.79 & 34.54 & 38.91 & 31.05 & 1.37 & 86 & 9746 & 135 & 191 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 8
# 96.78 & 32.58 & 37.98 & 28.52 & 1.31 & 79 & 9752 & 129 & 198 \\
# codebert-base
# Processing codebert-base for TOP 5, identifier 9
# 96.76 & 34.33 & 38.39 & 31.05 & 1.40 & 86 & 9743 & 138 & 191 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 11037 & 0 & 310 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 1
# 97.29 & 21.03 & 51.25 & 13.23 & 0.35 & 41 & 10998 & 39 & 269 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 2
# 97.26 & 23.59 & 49.48 & 15.48 & 0.44 & 48 & 10988 & 49 & 262 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 3
# 97.27 & 27.57 & 50.00 & 19.03 & 0.53 & 59 & 10978 & 59 & 251 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 4
# 96.88 & 23.71 & 35.71 & 17.74 & 0.90 & 55 & 10938 & 99 & 255 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 5
# 96.47 & 37.25 & 36.17 & 38.39 & 1.90 & 119 & 10827 & 210 & 191 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 6
# 96.70 & 35.52 & 38.15 & 33.23 & 1.51 & 103 & 10870 & 167 & 207 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 7
# 96.68 & 30.31 & 35.50 & 26.45 & 1.35 & 82 & 10888 & 149 & 228 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 8
# 96.58 & 35.12 & 36.46 & 33.87 & 1.66 & 105 & 10854 & 183 & 205 \\
# codebert-base
# Processing codebert-base for TOP 6, identifier 9
# 96.62 & 29.67 & 34.32 & 26.13 & 1.40 & 81 & 10882 & 155 & 229 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 0
# 97.24 & 34.67 & 49.19 & 26.76 & 0.78 & 91 & 12005 & 94 & 249 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 1
# 97.26 & 1.16 & 40.00 & 0.59 & 0.02 & 2 & 12096 & 3 & 338 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 2
# 97.23 & 15.23 & 46.27 & 9.12 & 0.30 & 31 & 12063 & 36 & 309 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 3
# 97.04 & 23.65 & 40.14 & 16.76 & 0.70 & 57 & 12014 & 85 & 283 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 4
# 96.70 & 28.02 & 34.63 & 23.53 & 1.25 & 80 & 11948 & 151 & 260 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 5
# 96.61 & 29.90 & 34.35 & 26.47 & 1.42 & 90 & 11927 & 172 & 250 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 6
# 96.76 & 27.12 & 35.21 & 22.06 & 1.14 & 75 & 11961 & 138 & 265 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 7
# 96.68 & 28.42 & 34.60 & 24.12 & 1.28 & 82 & 11944 & 155 & 258 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 8
# 96.60 & 30.08 & 34.34 & 26.76 & 1.44 & 91 & 11925 & 174 & 249 \\
# codebert-base
# Processing codebert-base for TOP 7, identifier 9
# 96.58 & 28.52 & 33.20 & 25.00 & 1.41 & 85 & 11928 & 171 & 255 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 13025 & 0 & 366 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 1
# 97.20 & 0.53 & 9.09 & 0.27 & 0.08 & 1 & 13015 & 10 & 365 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 2
# 97.18 & 23.79 & 45.38 & 16.12 & 0.55 & 59 & 12954 & 71 & 307 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 3
# 96.79 & 33.85 & 38.73 & 30.05 & 1.34 & 110 & 12851 & 174 & 256 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 4
# 96.56 & 32.94 & 35.31 & 30.87 & 1.59 & 113 & 12818 & 207 & 253 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 5
# 96.24 & 34.20 & 32.75 & 35.79 & 2.07 & 131 & 12756 & 269 & 235 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 6
# 96.53 & 28.62 & 32.75 & 25.41 & 1.47 & 93 & 12834 & 191 & 273 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 7
# 96.58 & 27.53 & 32.71 & 23.77 & 1.37 & 87 & 12846 & 179 & 279 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 8
# 96.41 & 26.56 & 30.10 & 23.77 & 1.55 & 87 & 12823 & 202 & 279 \\
# codebert-base
# Processing codebert-base for TOP 8, identifier 9
# 96.46 & 26.85 & 30.85 & 23.77 & 1.50 & 87 & 12830 & 195 & 279 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 0
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 13846 & 0 & 389 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 13846 & 0 & 389 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 2
# 97.26 & 3.47 & 46.67 & 1.80 & 0.06 & 7 & 13838 & 8 & 382 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 3
# 97.23 & 15.09 & 46.67 & 9.00 & 0.29 & 35 & 13806 & 40 & 354 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 4
# 97.05 & 23.36 & 40.25 & 16.45 & 0.69 & 64 & 13751 & 95 & 325 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 5
# 96.79 & 18.25 & 30.00 & 13.11 & 0.86 & 51 & 13727 & 119 & 338 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 6
# 96.35 & 33.84 & 33.50 & 34.19 & 1.91 & 133 & 13582 & 264 & 256 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 7
# 96.30 & 31.29 & 31.75 & 30.85 & 1.86 & 120 & 13588 & 258 & 269 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 8
# 96.19 & 31.00 & 30.65 & 31.36 & 1.99 & 122 & 13570 & 276 & 267 \\
# codebert-base
# Processing codebert-base for TOP 9, identifier 9
# 96.35 & 28.57 & 30.68 & 26.74 & 1.70 & 104 & 13611 & 235 & 285 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 0
# 97.25 & 14.88 & 48.00 & 8.80 & 0.27 & 36 & 14513 & 39 & 373 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 1
# 97.27 & 0.00 & 0.00 & 0.00 & 0.00 & 0 & 14552 & 0 & 409 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 2
# 97.22 & 9.17 & 42.86 & 5.13 & 0.19 & 21 & 14524 & 28 & 388 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 3
# 97.13 & 19.21 & 41.80 & 12.47 & 0.49 & 51 & 14481 & 71 & 358 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 4
# 96.50 & 22.97 & 28.89 & 19.07 & 1.32 & 78 & 14360 & 192 & 331 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 5
# 96.15 & 27.09 & 28.08 & 26.16 & 1.88 & 107 & 14278 & 274 & 302 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 6
# 96.17 & 27.92 & 28.76 & 27.14 & 1.89 & 111 & 14277 & 275 & 298 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 7
# 96.12 & 27.83 & 28.28 & 27.38 & 1.95 & 112 & 14268 & 284 & 297 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 8
# 96.28 & 28.17 & 29.86 & 26.65 & 1.76 & 109 & 14296 & 256 & 300 \\
# codebert-base
# Processing codebert-base for TOP 10, identifier 9
# 96.28 & 27.79 & 29.64 & 26.16 & 1.75 & 107 & 14298 & 254 & 302 \\
# Best identifier for codebert-base with TOP 2 is 6 with F1 score 0.4912
# 97.19 & 49.12 & 48.28 & 50.00 & 1.49 & 70 & 4952 & 75 & 70 \\
# Best identifier for codebert-base with TOP 3 is 8 with F1 score 0.3913
# 97.21 & 39.13 & 48.09 & 32.98 & 0.99 & 63 & 6774 & 68 & 128 \\
# Best identifier for codebert-base with TOP 4 is 5 with F1 score 0.3924
# 97.07 & 39.24 & 45.11 & 34.73 & 1.18 & 83 & 8437 & 101 & 156 \\
# Best identifier for codebert-base with TOP 5 is 3 with F1 score 0.3806
# 96.60 & 38.06 & 37.86 & 38.27 & 1.76 & 106 & 9707 & 174 & 171 \\
# Best identifier for codebert-base with TOP 6 is 5 with F1 score 0.3725
# 96.47 & 37.25 & 36.17 & 38.39 & 1.90 & 119 & 10827 & 210 & 191 \\
# Best identifier for codebert-base with TOP 7 is 0 with F1 score 0.3467
# 97.24 & 34.67 & 49.19 & 26.76 & 0.78 & 91 & 12005 & 94 & 249 \\
# Best identifier for codebert-base with TOP 8 is 5 with F1 score 0.3420
# 96.24 & 34.20 & 32.75 & 35.79 & 2.07 & 131 & 12756 & 269 & 235 \\
# Best identifier for codebert-base with TOP 9 is 6 with F1 score 0.3384
# 96.35 & 33.84 & 33.50 & 34.19 & 1.91 & 133 & 13582 & 264 & 256 \\
# Best identifier for codebert-base with TOP 10 is 8 with F1 score 0.2817
# 96.28 & 28.17 & 29.86 & 26.65 & 1.76 & 109 & 14296 & 256 & 300 \\
